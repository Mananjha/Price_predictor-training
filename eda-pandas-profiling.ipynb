# %%
import pandas as pd
from pandas_profiling import ProfileReport

# Load your dataset
df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()

# Create the ProfileReport object
profile = ProfileReport(df, title='Pandas Profiling Report', explorative=True)

# Generate the report
profile.to_file("output_report.html")
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 2
#       1 import pandas as pd
# ----> 2 from pandas_profiling import ProfileReport
#       4 # Load your dataset
#       5 df = pd.read_csv('gurgaon_properties_cleaned_v2.csv').drop_duplicates()
#
# ModuleNotFoundError: No module named 'pandas_profiling'

# %%
# !pip install pandas-profiling
# Out:
# Collecting pandas-profiling
#   Downloading pandas_profiling-3.6.6-py2.py3-none-any.whl (324 kB)
# Collecting ydata-profiling
#   Downloading ydata_profiling-4.17.0-py2.py3-none-any.whl (399 kB)
# Collecting minify-html>=0.15.0
#   Downloading minify_html-0.16.4-cp310-cp310-win_amd64.whl (2.4 MB)
# Collecting wordcloud>=1.9.3
#   Downloading wordcloud-1.9.4-cp310-cp310-win_amd64.whl (299 kB)
# Collecting phik<0.13,>=0.11.1
#   Downloading phik-0.12.5-cp310-cp310-win_amd64.whl (674 kB)
# Requirement already satisfied: jinja2<3.2,>=2.11.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (3.1.6)
# Requirement already satisfied: numpy<2.2,>=1.16.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.26.4)
# Requirement already satisfied: requests<3,>=2.24.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.32.5)
# Collecting imagehash==4.3.1
#   Downloading ImageHash-4.3.1-py2.py3-none-any.whl (296 kB)
# Collecting pydantic>=2
#   Downloading pydantic-2.11.9-py3-none-any.whl (444 kB)
# Collecting matplotlib<=3.10,>=3.5
#   Downloading matplotlib-3.10.0-cp310-cp310-win_amd64.whl (8.0 MB)
# Collecting numba<=0.61,>=0.56.0
#   Downloading numba-0.61.0-cp310-cp310-win_amd64.whl (2.8 MB)
# Requirement already satisfied: PyYAML<6.1,>=5.0.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (6.0.2)
# Collecting visions[type_image_path]<0.8.2,>=0.7.5
#   Downloading visions-0.8.1-py3-none-any.whl (105 kB)
# Collecting multimethod<2,>=1.4
#   Downloading multimethod-1.12-py3-none-any.whl (10 kB)
# Collecting dacite>=1.8
#   Downloading dacite-1.9.2-py3-none-any.whl (16 kB)
# Collecting statsmodels<1,>=0.13.2
#   Downloading statsmodels-0.14.5-cp310-cp310-win_amd64.whl (9.6 MB)
# Collecting filetype>=1.0.0
#   Downloading filetype-1.2.0-py2.py3-none-any.whl (19 kB)
# Collecting typeguard<5,>=3
#   Downloading typeguard-4.4.4-py3-none-any.whl (34 kB)
# Requirement already satisfied: seaborn<0.14,>=0.10.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (0.13.2)
# Requirement already satisfied: scipy<1.16,>=1.4.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (1.15.3)
# Requirement already satisfied: pandas!=1.4.0,<3.0,>1.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (2.3.2)
# Requirement already satisfied: tqdm<5,>=4.48.2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from ydata-profiling->pandas-profiling) (4.67.1)
# Requirement already satisfied: pillow in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from imagehash==4.3.1->ydata-profiling->pandas-profiling) (11.3.0)
# Collecting PyWavelets
#   Downloading pywavelets-1.8.0-cp310-cp310-win_amd64.whl (4.2 MB)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from jinja2<3.2,>=2.11.1->ydata-profiling->pandas-profiling) (3.0.2)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (2.9.0.post0)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (4.60.0)
# Requirement already satisfied: packaging>=20.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (25.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (0.12.1)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (3.2.4)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.3.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.4.9)
# Collecting llvmlite<0.45,>=0.44.0dev0
#   Downloading llvmlite-0.44.0-cp310-cp310-win_amd64.whl (30.3 MB)
# Requirement already satisfied: pytz>=2020.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pandas!=1.4.0,<3.0,>1.1->ydata-profiling->pandas-profiling) (2025.2)
# Requirement already satisfied: joblib>=0.14.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from phik<0.13,>=0.11.1->ydata-profiling->pandas-profiling) (1.5.2)
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-win_amd64.whl (2.0 MB)
# Requirement already satisfied: typing-extensions>=4.12.2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from pydantic>=2->ydata-profiling->pandas-profiling) (4.15.0)
# Requirement already satisfied: six>=1.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from python-dateutil>=2.7->matplotlib<=3.10,>=3.5->ydata-profiling->pandas-profiling) (1.17.0)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2.5.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (3.4.3)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from requests<3,>=2.24.0->ydata-profiling->pandas-profiling) (2025.8.3)
# Collecting patsy>=0.5.6
#   Using cached patsy-1.0.1-py2.py3-none-any.whl (232 kB)
# Requirement already satisfied: colorama in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from tqdm<5,>=4.48.2->ydata-profiling->pandas-profiling) (0.4.6)
# Collecting puremagic
#   Downloading puremagic-1.30-py3-none-any.whl (43 kB)
# Requirement already satisfied: attrs>=19.3.0 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (25.3.0)
# Requirement already satisfied: networkx>=2.4 in c:\users\dell\appdata\local\programs\python\python310\lib\site-packages (from visions[type_image_path]<0.8.2,>=0.7.5->ydata-profiling->pandas-profiling) (3.4.2)
# Installing collected packages: puremagic, multimethod, visions, typing-inspection, PyWavelets, pydantic-core, patsy, matplotlib, llvmlite, annotated-types, wordcloud, typeguard, statsmodels, pydantic, phik, numba, minify-html, imagehash, filetype, dacite, ydata-profiling, pandas-profiling
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.10.6
#     Uninstalling matplotlib-3.10.6:
# WARNING: visions 0.8.1 does not provide the extra 'type_image_path'
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'c:\\users\\dell\\appdata\\local\\programs\\python\\python310\\lib\\site-packages\\matplotlib\\backends\\_backend_agg.cp310-win_amd64.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.2.3; however, version 25.2 is available.
# You should consider upgrading via the 'C:\Users\DELL\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.
